# %%
from tools.utils import load_catalog
from tools.utils import load_xy
from global_settings import DATA_FOLDER
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import os

# %%
from sklearn.metrics import classification_report
y_true = [0, 1, 2, 2, 2, 3, 4]
y_pred = [0, 0, 2, 2, 1, 3, 4]
target_names = ['class 0', 'class 1', 'class 2', 'class 3', 'class 4']

# %%
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(12, 5))
plt.text(0.1, 0.5, classification_report(y_true, y_pred, target_names=target_names), fontdict= {'fontsize': 20}, 
         family = 'monospace', ha='center', va='center', animated=True) 
plt.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
from data.explore import distribution
distribution('ASAS')

# %%
from tools.utils import load_catalog
catalog = load_catalog('OGLE', 'whole')

# %%
sorted(list(catalog['N']))
# Out:
# [300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
# ...
