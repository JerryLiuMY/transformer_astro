# %%
from main import run_fold
from config.model_config import rnn_nums_hp, rnn_dims_hp, dnn_nums_hp
rnn_nums, rnn_dims, dnn_nums = rnn_nums_hp.domain.values, rnn_dims_hp.domain.values, dnn_nums_hp.domain.values
rnn_num, rnn_dim, dnn_num = rnn_nums[0], rnn_dims[0], dnn_nums[0]
hyper_param = {rnn_nums_hp: rnn_num, rnn_dims_hp: rnn_dim, dnn_nums_hp: dnn_num}

# %%
from main import run_fold, run
run('ASAS')
# Out:
# --- Starting trial: rnn_num_1-rnn_dim_25-dnn_num_1-2020-07-26--17-28-35
# {'rnn_nums': 1, 'rnn_dims': 25, 'dnn_nums': 1}
# 2020-07-26 17:28:35.535439 Loading ASAS train set
# 2020-07-26 17:28:39.619537 Loading ASAS valid set
# 2020-07-26 17:28:40.215432 Loading ASAS evalu set
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/200
# 17/17 [==============================] - 4s 206ms/step - loss: 0.8066 - accuracy: 0.1384 - k_accuracy: 1.0000 - precision: 0.1652 - recall: 0.0351 - auc: 0.4086 - val_loss: 2.0369 - val_accuracy: 0.0836 - val_k_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.3188 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/200
# ...

# %%
from tools.utils import load_catalog
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
train_catalog = load_catalog('ASAS', 'train')
catalog = load_catalog('ASAS', 'train')
catalog
# Out:
#               Path        Class    N
# 0       LCs/92.dat  Beta Persei  474
# 1      LCs/550.dat  Beta Persei  653
# 2     LCs/2245.dat  Beta Persei  284
# 3      LCs/499.dat  Beta Persei  681
# 4     LCs/2435.dat  Beta Persei  397
# ...            ...          ...  ...
# 2163  LCs/2230.dat   W Ursae Ma  577
# 2164  LCs/2214.dat   W Ursae Ma  523
# 2165  LCs/1146.dat   W Ursae Ma  246
# 2166   LCs/209.dat   W Ursae Ma  473
# 2167  LCs/1455.dat   W Ursae Ma  575
#
# [2168 rows x 3 columns]
