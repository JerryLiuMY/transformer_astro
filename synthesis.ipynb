# %%
import timesynth as ts
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from tools.run_synth import run_car, run_sin
run_sin()

# %%
import pandas as pd
pd.read_csv('/Users/mingyu/Desktop/lightcurve_data/ASAS/LCs/0.dat')
# Out:
#             mjd    mag  errmag
# 0    2622.54996  9.438   0.040
# 1    2623.53765  9.415   0.023
# 2    2627.53991  9.356   0.031
# 3    2628.53197  9.415   0.039
# 4    2629.52836  9.342   0.031
# ..          ...    ...     ...
# 189  4389.56873  9.480   0.049
# 190  4403.52749  9.342   0.035
# 191  4409.51910  9.462   0.067
# 192  4443.52868  9.828   0.069
# 193  4449.54457  9.742   0.044
#
# [194 rows x 3 columns]

# %%
from tools.run_synth import run_sin, run_gp, run_car

# %%
from config.data_config import data_config

# %%
data_config
# Out:
# {'n_rnn': 1,
#  'n_dnn': 1,
#  'h_rnn': 2,
#  'h_dnn': 2,
#  'bidi': False,
#  'epochs': 1000,
#  'batch_size': 128}

# %%
from tools.data_tools import cat_generator
gen = cat_generator('MACHO')

# %%
next(gen)
# Out:
# (array([array([[ 1.949510e+00, -2.900000e-02,  1.995520e+00, ..., -1.170000e-01,
#           1.974900e+00, -3.420000e-01],
#         [ 1.003160e+00, -3.000000e-03,  9.964200e-01, ..., -7.300000e-02,
#           1.101658e+01, -2.720000e-01],
#         [ 9.975600e-01, -9.500000e-02,  9.998200e-01, ...,  5.090000e-01,
#           2.007700e+00,  7.500000e-02],
#         ...,
#         [ 2.045160e+00, -3.800000e-02,  1.388108e+01, ..., -2.260000e-01,
#           1.999630e+00,  5.130000e-01],
#         [ 5.014990e+00,  3.130000e-01,  2.008870e+00, ...,  5.800000e-02,
#           3.996650e+00, -3.030000e-01],
#         [ 4.990670e+00, -1.121000e+00,  8.544077e+01, ...,  2.450000e-01,
#           2.004790e+00, -5.780000e-01]]),
#         array([[ 1.94686e+00, -1.10000e-02,  1.99554e+00, ...,  2.50000e-02,
#           9.90150e-01,  1.09000e-01],
#         [ 9.47010e-01,  7.00000e-03,  9.98750e-01, ..., -1.16000e-01,
#           1.00702e+00,  6.80000e-02],
# ...

# %%
import pandas as pd
pd.read_csv('/Users/mingyu/Desktop/lightcurve_data/LCs/J001143.94-824245.5.dat')
# Out:
#              mjd     mag  errmag
# 0   55291.959546  13.385   0.040
# 1   55294.208843  13.184   0.044
# 2   55294.208970  13.224   0.043
# 3   55294.341274  13.350   0.045
# 4   55294.605886  13.318   0.039
# 5   55294.671974  13.305   0.044
# 6   55294.738190  13.197   0.032
# 7   55294.804278  13.232   0.036
# 8   55294.870494  13.293   0.037
# 9   55294.936583  13.210   0.038
# 10  55294.936710  13.230   0.041
# 11  55295.002798  13.331   0.042
# 12  55295.201318  13.497   0.044
# 13  55295.267407  13.223   0.037
# 14  55295.333622  13.219   0.037
# 15  55295.532015  13.282   0.039
# 16  55295.598230  13.310   0.036
# 17  55295.664319  13.329   0.041
# 18  55295.664446  13.337   0.042
# 19  55295.730535  13.338   0.040
# 20  55295.796750  13.536   0.052
# 21  55295.862839  13.286   0.035
# 22  55295.929054  13.309   0.041
# 23  55295.995143  13.324   0.040
# 24  55296.259751  13.390   0.055
# 25  55474.005872  13.257   0.035
# 26  55474.270480  13.440   0.042
# ...

# %%
pd.read_csv('/Users/mingyu/Desktop/lightcurve_data/GAIA/catalog.csv', index_col=0)
# Out:
#                          ID    Class                         Path   N
# 0       4395790042666181888     RRAB  LCs/4395790042666181888.dat  47
# 1       4123081987663291136  MIRA_SR  LCs/4123081987663291136.dat  16
# 2       1748775099405304832     RRAB  LCs/1748775099405304832.dat  30
# 3       4041877208419516544     RRAB  LCs/4041877208419516544.dat  14
# 4       1441812897701323136     RRAB  LCs/1441812897701323136.dat  59
# ...                     ...      ...                          ...  ..
# 363137  5328589766073673600  MIRA_SR  LCs/5328589766073673600.dat  30
# 363138  6477559625882619648  MIRA_SR  LCs/6477559625882619648.dat  37
# 363139  4705173476343923200      RRC  LCs/4705173476343923200.dat  30
# 363140  4553097652294016384     RRAB  LCs/4553097652294016384.dat  59
# 363141  6856182983259212544     RRAB  LCs/6856182983259212544.dat  39
#
# [363142 rows x 4 columns]
