# %%
import timesynth as ts
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
pd.read_csv('/Users/mingyu/Desktop/34e9e4a8eef5b19d.csv')
# Out:
#          gvkey  datadate   fyear indfmt consol popsrc datafmt    tic  ajex  \
# 0         1000  19751231  1975.0   INDL      C      D     STD   AE.2   1.0
# 1         1000  19761231  1976.0   INDL      C      D     STD   AE.2   1.0
# 2         1000  19771231  1977.0   INDL      C      D     STD   AE.2   1.0
# 3         1001  19781231  1978.0   INDL      C      D     STD  AMFD.   1.0
# 4         1001  19791231  1979.0   INDL      C      D     STD  AMFD.   1.0
# ...        ...       ...     ...    ...    ...    ...     ...    ...   ...
# 405512  330942  20191231  2019.0   INDL      C      D     STD   BBUS   1.0
# 405513  331856  20181231  2018.0   INDL      C      D     STD   IMUX   1.0
# 405514  331856  20191231  2019.0   INDL      C      D     STD   IMUX   1.0
# 405515  332115  20181231  2018.0   INDL      C      D     STD   ARMP   1.0
# 405516  332115  20191231  2019.0   INDL      C      D     STD   ARMP   1.0
#
#        curcd  bkvlps  cshfd  epsfx costat   sic
# ...
